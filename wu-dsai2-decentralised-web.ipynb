# %% [markdown]
#  # Data Science and Artificial Intelligence II
#
#  Ownership, control, and access
#
#  Decentralised Web
#
#  Crozat, Baptiste
#
#  Sayah Karadji, Arian

# %% [markdown]
# ## Resources
#
# - [Getting started as a Solid developer](https://solidproject.org//developers/tutorials/getting-started)
# - https://docs.inrupt.com/developer-tools/javascript/client-libraries/tutorial/getting-started/)
# - [AccessArt by Kulha, R. & El Sirfy](https://github.com/RobbsX/AccessArt)

# %% [markdown]
# ## READ ME
#
# About the project
#
# This project investigate the usability of the [SOLID](https://solidproject.org/) specification to create a decentralised file sharing alternative.
#
# The goal is to setup user pods and create a system that let them exchange files securely and privately while retaining total control over the data and modalities.

# %% [markdown]
# ## 2024-06-06 Sumbission before Hackathon #1
#
#
# ### Progress made to date
#
# - Set up GitHub repository
# - Created two pods
# - Installed node.js & other dependencies
#
# ### Project specific goals for the Hackathon
#
# - Pods up and running
# - Test image storage and retrieval
# - Test file exchange between the twos pods
# - Look into encryption

# %% [markdown]
# ## Ideas Brainstorming
#
# File transfer using IPFS or Solid
#
# Personal Finance Manager:
# Objective: Create a financial management tool that uses transaction data stored in Solid Pods.
# Features:
# Expense tracking and budget management.
# Financial goal setting and progress tracking.
# Predictive analytics for future spending patterns.
#
# Collaborative Research Platform:
# Objective: Develop a platform for researchers to store, share, and analyze data collaboratively using Solid Pods.
# Features:
# Secure data sharing with granular access control.
# Tools for data cleaning, transformation, and visualization.
# Integration with statistical analysis and machine learning libraries.

# %% [markdown]
# First Idea: Use Solid Project to collect data in a pod and visaulize/analyze it. The data can be either health data (for example Apple Health or Strave) or finance data (Excel or any other kind of data format)
#
# Second Idea: Use IPFS to create a file transfer system similar to WeTransfer, it would be dezentralized and disappear after a period of time.

# %% [markdown]
# ## Creating a pod
#
# *Note: the following was done using a third party web app with GUI. Now let's try again the developer way!*
#
# We first used [iGrant](https://igrant.io/datapod.html) to create two pods. iGrant is a Swedish intermediation infrastructure provider for data exchange and verification services recommended by Solid through their official website. The registration flow is intuitive, using a user-friendly web browser interface. One must choose a username, password, provide full name and an email address to register. Once created, the credentials can be used to access a web drive application, that displays a set of folders and files.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# *Fig. X: iGrant registration page, used to create a Pod. Source: https://datapod.igrant.io/register*.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# *Fig. X: iGrant Pod's homepage. Source: Authors' screenshot.

# %% [markdown]
# ## Uploading files
#
# Once the Pod is created and accessed, files can be uploaded easily using the web application.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Sharing files
#
# Once a file is uploaded on the pod, it can be shared through the GUI using the 'Share' option. The access can easily be given to any other Pod owner from the user contact list.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# *Fig. X: iGrant's PodBrowser file sharing mechanism. Source: Authors' screenshot.

# %% [markdown]
# ### Install node.js
